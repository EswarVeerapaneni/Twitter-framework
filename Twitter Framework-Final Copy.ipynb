# %%
import pandas as pd
import tweepy

# %%
def getData(words, numtweet):

        db = pd.DataFrame(columns=['username','text','hashtags'])
        tweets = tweepy.Cursor(api.search_tweets,words,tweet_mode='extended')
        tweets = tweets.items(100)
        listOfTweets = [tweet for tweet in tweets]
        i = 1
        for tweet in listOfTweets:
                name = tweet.user.screen_name
                hashtags = tweet.entities['hashtags']
                text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
                        
                twee = [name, text, hashtext]
                print()
                print(f"User: {twee[0]}")
                print(f"Tweet: {twee[1]}")
                print(f"Hashtags: {twee[2]}")
                i = i+1

# %%
if __name__ == '__main__':


        consumer_key = "rsWNgTlQkE0HhiDHi3DxJjGc6"
        consumer_secret = "MZ7nhftytJdy5NsBFNJGjmhGmXkCWT74DmbTH7MJE8vIDWt56c"
        access_key = "1571650149742411777-EpiherGDvBdMQZxXvn5bFAAvlQGdnU"
        access_secret = "DWHGI6LNXVISc0OL2yWDbCO1fO5myrSBKNVh9gSxZGN0i"
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_key, access_secret)
        api = tweepy.API(auth)

        print("Enter HashTag that you want to search for on twitter")
        words = input()
        getData(words,100)
        print('Tweets Retrieved!')
# Out:
# Enter HashTag that you want to search for on twitter
# #phillies
#
# User: Chris63368859
# Tweet: RT @1992Pirates: OTD (9/20/1992): #Pittsburgh #Pirates Jeff King hits into an unassisted TRIPLE PLAY, executed by #Philadelphia #Phillies M…
# Hashtags: ['Pittsburgh', 'Pirates', 'Philadelphia', 'Phillies']
#
# User: LisaBro86874889
# Tweet: RT @PhillySportBday: September 16
# Happy Birthday!
# @mackhollins
# @QMikell27
# @AndyStudebaker
# @DesiRelafordFP
# @CorbenBone
#
# #Eagles #GoBirds #Fl…
# Hashtags: ['Eagles', 'GoBirds']
#
# User: Kenneth53773057
# Tweet: RT @sigg20: Athletes We Remember From the Past
# #Phillies #Cubs #Tigers #MLB #Nostalgia https://t.co/6AgsPPMH0X
# Hashtags: ['Phillies', 'Cubs', 'Tigers', 'MLB', 'Nostalgia']
#
# User: DaveMReports
# Tweet: After being off yesterday the #Phillies return to game action tonight as they take on the Toronto Blue Jays for a two-game series at Citizens Bank Park
#
# The pitching rotation for the Blue Jays series
#
# Tonight: Kyle Gibson
# Tomorrow: Zack Wheeler
#
# #RingTheBell    #TORvsPHI
# Hashtags: ['Phillies', 'RingTheBell', 'TORvsPHI']
#
# User: BallparkPalPHI
# Tweet: Top-rated #Phillies matchup vs Ross Stripling:
#
# Bryce Harper (A)
# A- matchup vs Stripling
#
# HR: 7.1% (+2.0)
# XBH: 5.1% (+0.3)
# Hit: 27.1% (+3.0)
# On Base: 32.8% (+0.6)
# Strikeout: 22.0% (-3.9)
#
# #TORvsPHI | #PHIvsTOR
# #RingTheBell https://t.co/eVoydP7QWE
# Hashtags: ['Phillies', 'TORvsPHI', 'PHIvsTOR', 'RingTheBell']
#
# User: MLBPlayoffScen
# Tweet: Scenario 3: The Philadelphia Phillies will be eliminated from NL East division title contention if the Phillies lose to the Blue Jays AND the Mets beat the Brewers today.
#
# #RingTheBell #Phillies #MLB
# Hashtags: ['RingTheBell', 'Phillies', 'MLB']
#
# User: POLIV411
# Tweet: RT @sigg20: Athletes We Remember From the Past
# #Phillies #Cubs #Tigers #MLB #Nostalgia https://t.co/6AgsPPMH0X
# Hashtags: ['Phillies', 'Cubs', 'Tigers', 'MLB', 'Nostalgia']
#
# User: HammerVegas
# Tweet: #MLB The Hammer playing #Reds +100 #Rays -155 #Cubs +135 #Phillies +105 #Mets -115 #Rangers +118 #Twins -125 #Giants +100 #Cards -105 #DBacks +260 follow The Hammer
# Hashtags: ['MLB', 'Reds', 'Rays', 'Cubs', 'Phillies', 'Mets', 'Rangers', 'Twins', 'Giants', 'Cards', 'DBacks']
#
# User: 26thYankee
# Tweet: RT @sigg20: Athletes We Remember From the Past
# #Phillies #Cubs #Tigers #MLB #Nostalgia https://t.co/6AgsPPMH0X
# Hashtags: ['Phillies', 'Cubs', 'Tigers', 'MLB', 'Nostalgia']
#
# User: sigg20
# Tweet: Athletes We Remember From the Past
# #Phillies #Cubs #Tigers #MLB #Nostalgia https://t.co/6AgsPPMH0X
# Hashtags: ['Phillies', 'Cubs', 'Tigers', 'MLB', 'Nostalgia']
#
# User: eazeee2004
# Tweet: RT @ToddZolecki: #Phillies placed INF Edmundo Sosa on the 10-day IL with a right hamstring strain. They recalled INF Yairo Muñoz from Tripl…
# Hashtags: ['Phillies']
#
# User: eazeee2004
# Tweet: RT @ToddZolecki: #Phillies postseason odds about the same despite last night’s loss, according to @fangraphs. Padres lost. Brewers idle. Bu…
# Hashtags: ['Phillies']
#
# User: eazeee2004
# Tweet: RT @ToddZolecki: #Phillies have a 2 1/2-game lead over San Diego and a 4 1/2-game lead over Milwaukee with 20 games to play. Phillies own t…
# Hashtags: ['Phillies']
#
# User: OctagonBaseball
# Tweet: Touching 100 with a power curve, that plays @dfb3_ #Phillies https://t.co/MH9cOb8cqJ
# Hashtags: ['Phillies']
#
# User: AndyFurmanFSR
# Tweet: RT @NLCarolynMuse: #OTD in #MLB history (9/19/1937):  Lefthanded pitcher, youth baseball instructor, and insurance salesman Chris Short was…
# Hashtags: ['OTD', 'MLB']
#
# User: JDaniel2033
# Tweet: 9/20/80
#
# Mike Schmidt reaches the 40 HR mark for the 2nd straight season as the #Phillies beat the #Cubs 7-3.
# Here is the rest of the day in 1980s Baseball: https://t.co/DoT5jBi6vN
# #RingTheBell https://t.co/sIIaE7M20i
# Hashtags: ['Phillies', 'Cubs', 'RingTheBell']
#
# User: TheReliefRoom
# Tweet: Today in Relief Room history 2002 Pedro Liriano is involved in a trade w/ Sal Fasano. It didn't even involve the #Phillies but I have a Big Sal HR ball &amp; he has a HOF mustache so it all works. https://t.co/TzwjkwJBz0
# Hashtags: ['Phillies']
#
# User: CallDT
# Tweet: What EAST Division is better this season in Major League Baseball, in your opinion: AL East OR NL East?
#
# #AL #NL #NLEast #ALEast #AmericanLeague #NationalLeague #baseball #MLB #sports #Mets #Phillies #Braves #Yankees #Rays #Bluejays
# Hashtags: ['AL', 'NL', 'NLEast', 'ALEast', 'AmericanLeague', 'NationalLeague', 'baseball', 'MLB', 'sports', 'Mets', 'Phillies', 'Braves', 'Yankees', 'Rays', 'Bluejays']
#
# User: RDixey92
# Tweet: RT @ShenkLarry: 😍⚾️OTD 1967: Steve Carlton (14-9) strikes out 16 but loses, 3-1. Winning team? Phillies, at Connie Mack Stadium, before 8,4…
# Hashtags: []
#
# User: MikeHink11
# Tweet: RT @ShenkLarry: 😍⚾️OTD 1967: Steve Carlton (14-9) strikes out 16 but loses, 3-1. Winning team? Phillies, at Connie Mack Stadium, before 8,4…
# Hashtags: []
#
# User: FightinPhillies
# Tweet: I am going to go live in 15 minutes for a Twitter Spaces broadcast on the Phillies.. a special edition of Phillies Talk Podcast! Hey @NBCSPhilly and @NBCSPhillies you took my podcast name on me, but do you broadcast on Twitter?
#
# #Phillies
# #MLB
# #BaseballTalkRadio.com
# Hashtags: ['Phillies', 'MLB', 'BaseballTalkRadio']
#
# User: FightinPhillies
# Tweet: Mets, Dodgers waltz into playoffs... will the Phillies wake up and smell the coffee tonight vs Toronto?
#
# https://t.co/XvoLrz874x
#
# #Phillies
# #MLB
# Hashtags: ['Phillies', 'MLB']
#
# User: ShenkLarry
# Tweet: 😍⚾️OTD 1967: Steve Carlton (14-9) strikes out 16 but loses, 3-1. Winning team? Phillies, at Connie Mack Stadium, before 8,466 crowd, Chris Short (8-11) tosses a 4-hitter. #phillies https://t.co/PrztQPnsIV
# Hashtags: ['phillies']
#
# User: ARodriguezVera
# Tweet: RT @grupo757_: ¡Tenemos un nuevo #MatchDay en la #MLB!
#
# Hoy veremos el enfrentamiento entre los #BlueJays y los #Phillies. ¿Estás preparado…
# Hashtags: ['MatchDay', 'MLB', 'BlueJays', 'Phillies']
#
# User: VeryClassyCook
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: PGHfan72
# Tweet: RT @1992Pirates: OTD (9/20/1992): #Pittsburgh #Pirates Jeff King hits into an unassisted TRIPLE PLAY, executed by #Philadelphia #Phillies M…
# Hashtags: ['Pittsburgh', 'Pirates', 'Philadelphia', 'Phillies']
#
# User: SmallBizPhilly
# Tweet: RT @phi_apparel_co: #shopsmall #smallbusiness #philadelphia #phillysmallbiz #phillysmallbusiness #philadelphiasmallbusiness #phillysports #…
# Hashtags: ['shopsmall', 'smallbusiness', 'philadelphia', 'phillysmallbiz', 'phillysmallbusiness', 'philadelphiasmallbusiness', 'phillysports']
#
# User: DrewDalton48
# Tweet: @JonathanMayo @MLBPipeline Is #Phillies Carlos De La Cruz on the radar as a top 100 prospect?
# Hashtags: ['Phillies']
#
# User: burruezoe
# Tweet: Please have a better week @Phillies, we need a red October. #RingTheBell #Phillies
# Hashtags: ['RingTheBell', 'Phillies']
#
# User: Amijares609
# Tweet: RT @grupo757_: ¡Tenemos un nuevo #MatchDay en la #MLB!
#
# Hoy veremos el enfrentamiento entre los #BlueJays y los #Phillies. ¿Estás preparado…
# Hashtags: ['MatchDay', 'MLB', 'BlueJays', 'Phillies']
#
# User: TorcatFevrin
# Tweet: RT @grupo757_: ¡Tenemos un nuevo #MatchDay en la #MLB!
#
# Hoy veremos el enfrentamiento entre los #BlueJays y los #Phillies. ¿Estás preparado…
# Hashtags: ['MatchDay', 'MLB', 'BlueJays', 'Phillies']
#
# User: grupo757_
# Tweet: Por otro lado, los #Phillies están en medio de la tabla de la LN Este con un global de 80-66, porcentaje de .548 y 44-31 en su parque. https://t.co/yhnQtGWilS
# Hashtags: ['Phillies']
#
# User: grupo757_
# Tweet: ¡Tenemos un nuevo #MatchDay en la #MLB!
#
# Hoy veremos el enfrentamiento entre los #BlueJays y los #Phillies. ¿Estás preparado?
#
# #G757 #Betting #Live #SportsBook #Juega #Gana #Football #19Sep l https://t.co/1d8Q8AsCdl https://t.co/le3pTS86jC
# Hashtags: ['MatchDay', 'MLB', 'BlueJays', 'Phillies', 'G757', 'Betting', 'Live', 'SportsBook', 'Juega', 'Gana', 'Football', '19Sep']
#
# User: osbsportsbet
# Tweet: A Race for October | #BlueJays vs #Phillies | OSB
#
# Watch: https://t.co/CzvAF1llR2
#
# #MLBbetting #MLBpicks #freepicks #bluejaysvsphillies
# Hashtags: ['BlueJays', 'Phillies', 'MLBbetting', 'MLBpicks', 'freepicks', 'bluejaysvsphillies']
#
# User: NikkiAiello21
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: TAloysius42
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: Fridaygirl1969
# Tweet: RT @Tals_BB_Column: Please Retweet my latest article @sportstalkphl if you like it. Thank you.
#
# https://t.co/meMFY3Q8Ls
#
# #Phillies #RingThe…
# Hashtags: ['Phillies']
#
# User: DiabeticJew
# Tweet: Are the #Phillies making the playoffs?
# Hashtags: ['Phillies']
#
# User: bluwand
# Tweet: $YCRM Yuenglings Ice Cream-100 YEARS of tradition🍦🍧🍨🚀 $AMC $GME $YCRM $RUM $DWAC $PHUN $BBBY $BBIG $MDLZ $WISH $WBD $WMT $BROS #Rumble  #IceCream #Baskinrobbins #bennjerrys #HarryPotter #Tailgate #EaglesFootball #EaglesvsVikings #Steelers #PennState #Phillies #Pirates #MOASS https://t.co/pVUy0aRX3W
# Hashtags: ['Rumble', 'IceCream', 'Baskinrobbins', 'bennjerrys', 'HarryPotter', 'Tailgate', 'EaglesFootball', 'EaglesvsVikings', 'Steelers', 'PennState', 'Phillies', 'Pirates', 'MOASS']
#
# User: ShenkLarry
# Tweet: 😍⚾️GOOD MORNING! Mickey Morandini pulls off first unassisted triple play in Phillies history OTD 1992. Happened in the 6th inning of 3-2 loss in Pittsburgh. #phillies https://t.co/6EK0Wfh2xu
# Hashtags: ['phillies']
#
# User: ajt461
# Tweet: Let’s keep the positive vibes going after a great #Eagles win and let’s get back behind the #Phillies tonight!
#
# #FlyEaglesFly #RingTheBell #NoOneLikesUs
# Hashtags: ['Eagles', 'Phillies', 'FlyEaglesFly', 'RingTheBell', 'NoOneLikesUs']
#
# User: PhillySportBday
# Tweet: September 20
# Happy Birthday!
# @tommyjeter98
# @RHartzy18
# @srmig77
#
# #Eagles #GoBirds #FlyEaglesFly #76ers #Sixers #PhilaUnite #Phillies #RingTheBell #Flyers #Doop https://t.co/06XUXczNeq
# Hashtags: ['Eagles', 'GoBirds', 'FlyEaglesFly', '76ers', 'Sixers', 'PhilaUnite', 'Phillies', 'RingTheBell', 'Flyers', 'Doop']
#
# User: BallparkPal_TOR
# Tweet: Citizens Bank Park (9/20)
# #BlueJays @ #Phillies
#
# Wind: 9 mph ↘, Impact: High
# Temp: 78° (+2° vs park avg)
# HRs: +14%, XBH: +6%, Runs: +6.7%
#
# #BallparkPalParkPreviews https://t.co/OOagFsaoc3
# Hashtags: ['BlueJays', 'Phillies', 'BallparkPalParkPreviews']
#
# User: 814Pirates
# Tweet: RT @1992Pirates: OTD (9/20/1992): #Pittsburgh #Pirates Jeff King hits into an unassisted TRIPLE PLAY, executed by #Philadelphia #Phillies M…
# Hashtags: ['Pittsburgh', 'Pirates', 'Philadelphia', 'Phillies']
#
# User: lorie_theo
# Tweet: @RapsLeafsJays @KarenSoutar1 @MagneticTurtle9 @drewtheprinter @IAmtheSun420 @bluejaysfankim @ElaineStanley5 @biggles14 @LiferJays @SeatGiant @ForCanucksSake @KLgfeld1 @darrylw71 @Parker18YYZ @CathieBargenda @nickofthejays @LJ9111011 @bluejayshalifax @grounder761 @RogersCentre @Sportsnet Let's just worry about winning. The #BlueJays
# are hot but so are the #Phillies.
# Hashtags: ['BlueJays', 'Phillies']
#
# User: FrankKlose
# Tweet: Any questions for my @973espn #Phillies mailbag this morning?
# Hashtags: ['Phillies']
#
# User: 1992Pirates
# Tweet: OTD (9/20/1992): #Pittsburgh #Pirates Jeff King hits into an unassisted TRIPLE PLAY, executed by #Philadelphia #Phillies Mickey Morandini. But King redeemed himself in the 13th, plating the winning run! #LetsGoBucs
#
#  https://t.co/W5PEJv8XNA
# Hashtags: ['Pittsburgh', 'Pirates', 'Philadelphia', 'Phillies', 'LetsGoBucs']
#
# User: freddyandfoxy3
# Tweet: #Phillies #ringthebell rejoice the bot also hates Pete Alonso. https://t.co/cCeREsLSLI
# Hashtags: ['Phillies', 'ringthebell']
#
# User: oriolesrise
# Tweet: RT @Brian_Giacobbe: #Happybirthday Dave Gallagher! #autograph @DaveGallagher22 @Mets @Topps #Mets #LGM #indians #Guardians #whitesox #oriol…
# Hashtags: ['Happybirthday', 'autograph', 'Mets', 'LGM', 'indians', 'Guardians', 'whitesox']
#
# User: BaseballYodaWX
# Tweet: The #MLB recap for Monday September 19 now posted, all episodes at https://t.co/6M8GU608uT or download directly from https://t.co/KYzwSweou0 #Rangers #Astros #Angels #Mariners #Athletics #Mets #Braves #Phillies #Marlins #Nationals #Cubs #Cardinals #Brewers #Reds #Pirates
# Hashtags: ['MLB', 'Rangers', 'Astros', 'Angels', 'Mariners', 'Athletics', 'Mets', 'Braves', 'Phillies', 'Marlins', 'Nationals', 'Cubs', 'Cardinals', 'Brewers', 'Reds', 'Pirates']
#
# User: FrednewF1fan4
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: Jimbo_Mont
# Tweet: On this day in 1964 the Phillies beat the Dodgers 3-2 for their 90th win of the season.  Unfortunately this would be their last win in September.
#
# #Phillies #Philly #RingTheBell
#
# This Day in Philly Sports History - September 20, 2022 https://t.co/jeLXRHIdxJ via @YouTube
# Hashtags: ['Phillies', 'Philly', 'RingTheBell']
#
# User: joemalone9
# Tweet: RT @Tals_BB_Column: Please Retweet my latest article @sportstalkphl if you like it. Thank you.
#
# https://t.co/meMFY3Q8Ls
#
# #Phillies #RingThe…
# Hashtags: ['Phillies']
#
# User: SportsCardBOT
# Tweet: RT @Brian_Giacobbe: #Happybirthday Dave Gallagher! #autograph @DaveGallagher22 @Mets @Topps #Mets #LGM #indians #Guardians #whitesox #oriol…
# Hashtags: ['Happybirthday', 'autograph', 'Mets', 'LGM', 'indians', 'Guardians', 'whitesox']
#
# User: FrankBucco228
# Tweet: #Phillies are 3.5 if you count the tie breaker. No reason to panic. .500 baseball going into a soft road trip will do the trick #MLB #wildcardrace
# Hashtags: ['Phillies', 'MLB', 'wildcardrace']
#
# User: raw_chili
# Tweet: Hector Neris clinches the division 🥲
#
# https://t.co/Ez0oqjUBga
#
# #Baseball #MajorLeagueBaseball #MLB #MLBNationalLeague #MLBNationalLeagueEast #Pennsylvania #Philadelphia #PhiladelphiaPhillies #Phillies https://t.co/HSCfAHrUOj
# Hashtags: ['Baseball', 'MajorLeagueBaseball', 'MLB', 'MLBNationalLeague', 'MLBNationalLeagueEast', 'Pennsylvania', 'Philadelphia', 'PhiladelphiaPhillies', 'Phillies']
#
# User: Brian_Giacobbe
# Tweet: #Happybirthday Dave Gallagher! #autograph @DaveGallagher22 @Mets @Topps #Mets #LGM #indians #Guardians #whitesox #orioles #Angels #braves #phillies #MLB #topps https://t.co/fY7ZhwtMeM
# Hashtags: ['Happybirthday', 'autograph', 'Mets', 'LGM', 'indians', 'Guardians', 'whitesox', 'orioles', 'Angels', 'braves', 'phillies', 'MLB', 'topps']
#
# User: tonyspicks
# Tweet: Toronto Blue Jays vs Philadelphia Phillies 9/20/2022 Picks Predictions Previews
#
# https://t.co/LcAwA0AuKK
#
# #odds #picks #MLB #MLBpicks #MLBparlay #MLBbetting #MLBbettingpicks #MLBprediction #prediction #parlay #freepicks #expertpicks #sportspicks #baseballpicks #BlueJays #Phillies
# Hashtags: ['odds', 'picks', 'MLB', 'MLBpicks', 'MLBparlay', 'MLBbetting', 'MLBbettingpicks', 'MLBprediction', 'prediction', 'parlay', 'freepicks', 'expertpicks', 'sportspicks', 'baseballpicks', 'BlueJays', 'Phillies']
#
# User: brett5355sports
# Tweet: Always a nice morning after an #EAGLES W, and #Phillies gain .5 w/o even playing.
# Also for those perched on the Walt or Ben, the other teams in this WC race are not exactly on a tear last 10 games.
# #FlyEaglesFly
# #RingTheBell
# #LetsGoPhillies https://t.co/SIZHTOe71n
# Hashtags: ['EAGLES', 'Phillies', 'FlyEaglesFly', 'RingTheBell', 'LetsGoPhillies']
#
# User: JamesWa06893282
# Tweet: RT @philliesbell: OTD 1959: Richie Ashburn sets a new #Phillies career record when he singles for the 2,212th hit of his career. It breaks…
# Hashtags: ['Phillies']
#
# User: JamesWa06893282
# Tweet: RT @philliesbell: OTD 1983: #Phillies second baseman Joe Morgan homers twice on his 40th birthday leading a 7-6 win over Saint Louis at Vet…
# Hashtags: ['Phillies']
#
# User: JamesWa06893282
# Tweet: RT @philliesbell: Remembering #Phillies 1992 Wall of Famer Chris Short on the 85th anniversary of his birth (RIP 1991). The southpaw won 13…
# Hashtags: ['Phillies']
#
# User: Mcguoirk22
# Tweet: RT @Tals_BB_Column: Please Retweet my latest article @sportstalkphl if you like it. Thank you.
#
# https://t.co/meMFY3Q8Ls
#
# #Phillies #RingThe…
# Hashtags: ['Phillies']
#
# User: Tals_BB_Column
# Tweet: Please Retweet my latest article @sportstalkphl if you like it. Thank you.
#
# https://t.co/meMFY3Q8Ls
#
# #Phillies #RingTheBell
# Hashtags: ['Phillies', 'RingTheBell']
#
# User: PhilliesViews
# Tweet: MLB rising prospects: Jordan Westburg finishing hot, Gordon Graceffo dominates #PhiladelphiaPhillies #PhilliesTalk #Phillies https://t.co/FJohJNDJIf
# Hashtags: ['PhiladelphiaPhillies', 'PhilliesTalk', 'Phillies']
#
# User: linda_aviles13
# Tweet: RT @philliesbell: The #Phillies were off on Monday. However, their ‘Magic Number’ to clinch an NL postseason berth dropped to 13 as MIL was…
# Hashtags: ['Phillies']
#
# User: nynjpaweather
# Tweet: The weather impacts for tonight's #Mets, #Phillies, and #Yankees games are now updated!
#
# https://t.co/QQotx1sL13
# Hashtags: ['Mets', 'Phillies', 'Yankees']
#
# User: DaBadBoy13
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: timberelk
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: qualityatstat
# Tweet: PHI @ ATL Win Probability from 9/18/22
#  #Phillies (#RingTheBell) @ #Braves (#ForTheA) https://t.co/CwkhsK7pE0
# Hashtags: ['Phillies', 'RingTheBell', 'Braves', 'ForTheA']
#
# User: caden_martman62
# Tweet: RT @philliesbell: The #Phillies were off on Monday. However, their ‘Magic Number’ to clinch an NL postseason berth dropped to 13 as MIL was…
# Hashtags: ['Phillies']
#
# User: marioanthonyXIX
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: philliesbell
# Tweet: The #Phillies were off on Monday. However, their ‘Magic Number’ to clinch an NL postseason berth dropped to 13 as MIL was beaten by the NYM. https://t.co/erRtyioeZa
# Hashtags: ['Phillies']
#
# User: theBBSN
# Tweet: RT @theAJJShow: The last time I requested fans of a team come on the show, I surprised them with a #Phillies sports icon who joined in on t…
# Hashtags: ['Phillies']
#
# User: theAJJShow
# Tweet: The last time I requested fans of a team come on the show, I surprised them with a #Phillies sports icon who joined in on the conversation.  DM me bird fans. I need a couple of @Eagles fans on Wednesday night. #FlyEaglesFly
# Hashtags: ['Phillies', 'FlyEaglesFly']
#
# User: MermaidMom44
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: balloongarden_
# Tweet: メッツが決めたってことは大谷さんの弟分のモジャっ子マーシュがいるフィリーズはポストシーズン進めなかったって事なのかな？
# #大谷翔平 #ShoheiOhtani #オオタニサン #エンゼルス #Angels #MLB #Mets #Phillies #MARSH https://t.co/h3oPVQi1aY
# Hashtags: ['大谷翔平', 'ShoheiOhtani', 'オオタニサン', 'エンゼルス', 'Angels', 'MLB', 'Mets', 'Phillies', 'MARSH']
#
# User: carl_j_angel
# Tweet: The #BlueJays are hot and so are the #Phillies let's hope a brawl doesn't start when these two meet. #NextLevel
# Hashtags: ['BlueJays', 'Phillies', 'NextLevel']
#
# User: philliesbell
# Tweet: RT @philliesbell: Remembering #Phillies 1992 Wall of Famer Chris Short on the 85th anniversary of his birth (RIP 1991). The southpaw won 13…
# Hashtags: ['Phillies']
#
# User: Backlotphillfan
# Tweet: RT @philliesbell: OTD 1983: #Phillies second baseman Joe Morgan homers twice on his 40th birthday leading a 7-6 win over Saint Louis at Vet…
# Hashtags: ['Phillies']
#
# User: philliesbell
# Tweet: RT @philliesbell: OTD 1983: #Phillies second baseman Joe Morgan homers twice on his 40th birthday leading a 7-6 win over Saint Louis at Vet…
# Hashtags: ['Phillies']
#
# User: philliesbell
# Tweet: RT @philliesbell: OTD 1959: Richie Ashburn sets a new #Phillies career record when he singles for the 2,212th hit of his career. It breaks…
# Hashtags: ['Phillies']
#
# User: BomberBreaks
# Tweet: Bryson Stott /50 Gold Wave Refractor Rookie Auto pulled last night from our @topps Chrome Baseball breaks! 💥💥
# @bryson_stott10
# #philadelphiaphillies #casebreaks #mlb #boxbreaks #baseballcards #autograph #rookie #prospect #refractor #phillies #toppschrome https://t.co/1byjqRKmay
# Hashtags: ['philadelphiaphillies', 'casebreaks', 'mlb', 'boxbreaks', 'baseballcards', 'autograph', 'rookie', 'prospect', 'refractor', 'phillies', 'toppschrome']
#
# User: raw_chili
# Tweet: Petition for this to be the new #Phillies Win post
#
# https://t.co/Gzbp3pJzm4
#
# #Baseball #MajorLeagueBaseball #MLB #MLBNationalLeague #MLBNationalLeagueEast #Pennsylvania #Philadelphia #PhiladelphiaPhillies https://t.co/mMSB9DVIBU
# Hashtags: ['Phillies', 'Baseball', 'MajorLeagueBaseball', 'MLB', 'MLBNationalLeague', 'MLBNationalLeagueEast', 'Pennsylvania', 'Philadelphia', 'PhiladelphiaPhillies']
#
# User: ChrisDiFran86
# Tweet: RT @ChrisDiFran86: 🚨NEW EPISODE🚨
#
# Ty Gonzalez (@danegnzlz) of Locked On Mariners (@LO_Mariners) / #Phillies Weekly Recap:
#
# https://t.co/67…
# Hashtags: ['Phillies']
#
# User: AllenLiverSon
# Tweet: RT @ECAP_CITY: New Fitteds will be releasing online - Thurs 09/22/22. ⏰ 6PM EST
#
# https://t.co/sRGPb1KufA
#
# -
#
# @neweracapstyle #neweracapsty…
# Hashtags: []
#
# User: AllSportsDiva
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: MaDubbs
# Tweet: Brewers loss, so that is good for the #phillies
# Hashtags: ['phillies']
#
# User: GrubmanJB
# Tweet: @64PhilliesFan Yeah on offense. D still makes me nervous but nice second int   Meanwhile #Phillies better wake up
# Hashtags: ['Phillies']
#
# User: Liverpotlian
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: MikeFrohwirth
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: runthedamnballx
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: Marc_wit_a_C
# Tweet: Bryce Harper sitting in Mike Trout’s #Eagles seats is certainly a flex.
# #FlyEaglesFly
# #MondayNightFootball
# #Phillies
# #RingTheBell
# @DSM_Media https://t.co/SbhTJkg41X
# Hashtags: ['Eagles', 'FlyEaglesFly', 'MondayNightFootball', 'Phillies', 'RingTheBell']
#
# User: laxietoo
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: domturn__heads
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: Just_BoutBread
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: JamesWa06893282
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: jaime_netkowicz
# Tweet: RT @sigg20: New Feature
# Familiar Faces in Different Places
# #Mets #Phillies #Twins #WhiteSox #MLB #nostalgia https://t.co/YVZNF2PvrS
# Hashtags: ['Mets', 'Phillies', 'Twins', 'WhiteSox', 'MLB', 'nostalgia']
#
# User: DennisMauler
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
#
# User: AmberCarlance
# Tweet: RT @mattrappasports: “The Beard” James Harden and MV3 Bryce Harper at the Eagles home opener! #FlyEaglesFly  #Sixers #Phillies https://t.co…
# Hashtags: ['FlyEaglesFly', 'Sixers', 'Phillies']
# Tweets Retrieved!
